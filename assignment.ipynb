# %% [markdown]
# DECLARE VARIABLES FOR INTEGERS

# %%
a=10
print(a)
b=17
print(b)
# Out:
# 10
# 17

# %% [markdown]
# PYTHON BBOLEAN EXPRESSIONS

# %%
print(11==12)
# Out:
# False

# %%
print(17>11)
# Out:
# True

# %%
print(7!=10)
# Out:
# True

# %%
print(74>=89)
# Out:
# False

# %%
print(26>=13)
# Out:
# True

# %%
print(12==11)
# Out:
# False

# %% [markdown]
# INPUT OPERATORS IN PYTHON

# %%
name=input("what is your name")
print("my name is",name)
# Out:
# my name is Sanaullah Durrani

# %% [markdown]
# INPUT INTEGERS FROM USER

# %%
age=int(input("your age?"))
print("my age is",age)
# Out:
# my age is 21

# %% [markdown]
# ANY INPUT FROM USER

# %%
x=int(input("enter a number"))
print("value is",x)
# Out:
# value is 18

# %% [markdown]
# PRINTING SINGLE AND DOUBLE QUOTO IN SINGLE LINE

# %%
print('Rehan says,"Lets play PUBG"')
# Out:
# Rehan says,"Lets play PUBG"
