# %% [markdown]
# PRINT HELLO WORLD

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# PRINT STRING VALUE AND INTEGER IN A SINGLE LINE

# %%
print("kakarot",10)
# Out:
# kakarot 10

# %% [markdown]
# COMMENTS IN PYHTON

# %%
# HASHTAG IN START OF LINE IS USED FOR SINGLE LINE COMMENTS IN PYHTON

# %% [markdown]
# MULTIPLE LINES COMMENTS IN PYHTHON

# %%
"""MANY
LINES
COMMENTS"""

# %% [markdown]
# ARTHEMATIC OPERATIONS

# %% [markdown]
# SUM OF NUMBERS

# %%
print(7+18)
# Out:
# 25

# %% [markdown]
# SUBTRACTION

# %%
print(19-6)
# Out:
# 13

# %% [markdown]
# MULTIPLICATION

# %%
print(8*8)
# Out:
# 64

# %% [markdown]
# DIVISION

# %%
print(16/4)
# Out:
# 4.0

# %% [markdown]
# DECLARE VARIABLE

# %%
X="kakarot"
print(X)
# Out:
# kakarot

# %% [markdown]
# DECLARING INTEGERS

# %%
x=0,9,7,4
print(x)
# Out:
# (0, 9, 7, 4)

# %% [markdown]
# ASSIGNING VALUES TO MULTIPLE VARIABLES

# %%
x,y,z= "KAKAROT","AKAZA","AIZEN"
print(x)
print(y)
print(z)
# Out:
# KAKAROT
# AKAZA
# AIZEN

# %% [markdown]
# ASSIGNING SAME VALUE TO MULTIPLE VARIABLES

# %%
a=b=c = 78
print(a)
print(b)
print(c)
# Out:
# 78
# 78
# 78

# %% [markdown]
# DECLARE VARIABLE AND THEIR ADDITION

# %%
a=17
b=18

print(a+b)
# Out:
# 35
